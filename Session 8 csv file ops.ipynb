# %%
import csv

reader
DictReader

writer 
DictWriter

# %%
fp = open("test.csv","r")
fp.close()

# %%
import csv
with open("test.csv","r") as fp:
    reader = csv.reader(fp)
    for row in reader:
        print(row)
    fp.close()
# Out:
# ['Name ', 'Email', 'Contact']
# ['ABC', 'ABC@gmail.com', '9123456789']
# ['PQR', 'PQR@gmail.com', '9123456777']
# ['XYZ', 'XYZ@gmail.com', '9123456888']
# ['RST', 'RST@gmail.com', '9123456888']

# %%
import csv
with open("test.csv","r") as fp:
    reader = csv.reader(fp)
    print(next(reader))
    print(next(reader))
    print(next(reader))
    
#     for value in range(2):
#         print(next(reader))

#     for row in reader:
#         print(row)
    
#     print(fp.tell())
#     fp.seek(0)
#     print(fp.tell())


    fp.close()
# Out:
# ['Name ', 'Email', 'Contact']
# ['ABC', 'ABC@gmail.com', '9123456789']
# ['PQR', 'PQR@gmail.com', '9123456777']

# %%
import csv
with open("test.csv","r") as fp:
    with open("test2.csv","w") as fp1:
        writer = csv.DictWriter(fp1,fieldnames=['Name ','Email','Contact'],lineterminator = "\n")
        reader = csv.DictReader(fp)
        d = next(reader)
        writer.writerow(d)
        fp1.close()
        
    print(next(reader))
    fp.close()
# Out:
# OrderedDict([('Name ', 'PQR'), ('Email', 'PQR@gmail.com'), ('Contact', '9123456777')])

# %%
import csv
with open("test.csv","a+") as fp:
    writer = csv.writer(fp)
    writer.writerow(['QWE','QWE@gmail.com',"914578899"])
    fp.close()

# %%
import csv
with open("test.csv","a+") as fp:
    writer = csv.writer(fp,lineterminator="\n")
    writer.writerows([['RET','QWE@gmail.com',"914578899"],['YTR','poi@gmail.com',"914578899"]])
    fp.close()

# %%
help(csv)
# Out:
# Help on module csv:
#
# NAME
#     csv - CSV parsing and writing.
#
# DESCRIPTION
#     This module provides classes that assist in the reading and writing
#     of Comma Separated Value (CSV) files, and implements the interface
#     described by PEP 305.  Although many CSV files are simple to parse,
#     the format is not formally defined by a stable specification and
#     is subtle enough that parsing lines of a CSV file with something
#     like line.split(",") is bound to fail.  The module supports three
#     basic APIs: reading, writing, and registration of dialects.
#
#
#     DIALECT REGISTRATION:
#
#     Readers and writers support a dialect argument, which is a convenient
#     handle on a group of settings.  When the dialect argument is a string,
#     it identifies one of the dialects previously registered with the module.
#     If it is a class or instance, the attributes of the argument are used as
#     the settings for the reader or writer:
#
#         class excel:
# ...

# %%
import csv

with open("test.csv","a+") as fp:
    writer = csv.DictWriter(fp,fieldnames=['Name ','Email','Contact'],lineterminator="\n")
    writer.writerow({"Name ":'THN',"Contact":"914578899"})
    fp.close()

# %%
www.magicbrick.com => get/post response
get = > 
post => 


html  data

# %%
requests 
beautifulsoup

# %%
pip install requests 
pip install BeautifulSoup4

# %%
<html>
    <head></head>
    <body>
        <div id ="1" class="price">
            <a href="www.google.com">Click Here</a>
            <p>Sample text</p>
        </div>
        <img src="e://a.jpg">
    </body>

</html>

# %%
import requests
from bs4 import BeautifulSoup

# %%
response = requests.get("https://www.magicbricks.com/property-for-sale/residential-real-estate?proptype=Multistorey-Apartment,Builder-Floor-Apartment,Penthouse,Studio-Apartment&cityName=Bangalore")
print(response.content)
print(response.status_code)
# Out:
# b'\n<!DOCTYPE html>\n<html>\n<head>\n<meta charset="UTF-8">\n<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n<meta name="viewport" content="width=device-width, initial-scale=1">\n<meta name="google-signin-client_id" content="614944930403-u1s9tmqebd273mutmdhmsngnhvivgd6a.apps.googleusercontent.com">\n<link rel="dns-prefetch preconnect" href="//cdn.staticmb.com"/>\n<link rel="dns-prefetch preconnect" href="//img.staticmb.com"/>\n<link rel="dns-prefetch preconnect" href="//b.scorecardresearch.com">\n<link rel="dns-prefetch preconnect" href="//www.googleadservices.com">\n<link rel="dns-prefetch preconnect" href="//stats.g.doubleclick.net">\n<link rel="dns-prefetch preconnect" href="//ase.clmbtech.com">\n<link rel="dns-prefetch preconnect" href="//ingestor.magicbricks.com">\n<link rel="dns-prefetch preconnect" href="//maps.googleapis.com">\n<link rel="dns-prefetch preconnect" href="//www.googletagmanager.com">\n<title>Flats in Bangalore - Flats for Sale in Bangalore</title
# ...

# %%
404 => Page not found 
401
403
407
500
503

# %%
soup = BeautifulSoup(response.content,"html.parser")

# %%
DOM :                   soup
                        html
        head                            body
                                   div           img 
                            a             p

# %%
top to bottom 
bottom to top
sideways

# %%
find("div")
find_all("div")

find_parent()
find_parents()

find_sibling
find_siblings("")

# %%
import requests
from bs4 import BeautifulSoup

response = requests.get("https://www.magicbricks.com/property-for-sale/residential-real-estate?proptype=Multistorey-Apartment,Builder-Floor-Apartment,Penthouse,Studio-Apartment&cityName=Bangalore")
soup = BeautifulSoup(response.content,"html.parser")

# %%
price = soup.find("div", attrs={"class":"m-srp-card__price"})
print(price.text)
# Out:
# ₹ 1.33 Cr

# %%
card = soup.find("div",attrs = {"class":"m-srp-card__container"})
price = card.find("div", attrs={"class":"m-srp-card__price"})
title = card.find("a",attrs = {"class":"m-srp-card__title"})
img = card.find("img",attrs ={"class":"m-photo__img lazy"})
img_link = img.get("data-src")
print(img_link)

response3 = requests.get(img_link)
img_new = open("test_img.jpg","wb")
img_new.write(response3.content)
img_new.close()
# reponse2 = requests.get(title.get("href"))
# soup2 = BeautifulSoup(reponse2.content,"html.parser")
# agent_name = soup2.find("p",attrs = {"class":"CA_agent_name"})
# if agent_name:
#     agent_text = agent_name.text
# else:
#     agent_text = None

# title_text = title.text.replace("\n", " ")
# area = card.find("div",attrs = {"class":"m-srp-card__summary__info"})
# print("{} {} {} {}".format(title_text,price.text,area.text,agent_text))
# Out:
# https://img.staticmb.com/mbimages/project/Photo_h310_w462/2018/11/14/Project-Photo-19-Purva-Highlands-Bangalore-5019314_533_800_310_462.jpg

# %%
cards = soup.find_all("div",attrs = {"class":"m-srp-card__container"})
for card in cards:
    price = card.find("div", attrs={"class":"m-srp-card__price"})
    if price :
        price_text = price.text
    else:
        price_text = None
    title = card.find("a",attrs = {"class":"m-srp-card__title"})
    reponse2 = requests.get(title.get("href"))
    soup2 = BeautifulSoup(reponse2.content,"html.parser")
    agent_name = soup2.find("p",attrs = {"class":"CA_agent_name"})
    if agent_name:
        agent_text = agent_name.text
    else:
        agent_text = None

    title_text = title.text.replace("\n", " ")
    area = card.find("div",attrs = {"class":"m-srp-card__summary__info"})
    if area:
        area_text = area.text
    else:
        area_text = None
    print("{} \t\t {} \t\t {}\t\t{}".format(title_text,price_text,area_text,agent_text))
# Out:
#   3 BHK Apartment  for Sale in Kanakapura Road  		 ₹ 96.1 Lac 		 1841 sqft
# Puravankara Puravankara
#
#   4 BHK Apartment  for Sale in Rt Nagar  		 ₹ 5.16 Cr 		 3969 sqft
# Gayathri
#
#   3 BHK Apartment  for Sale in Whitefield  		 ₹ 78.5 Lac 		 1600 sqft
# Ajay Kumar
#
#   2 BHK Apartment  for Sale in Sarjapur Road  		 ₹ 54.5 Lac 		 1229 sqft		None
#   3 BHK Apartment  for Sale in Electronics City Phase 1, Electronic City  		 ₹ 48 Lac 		 1455 sqft
# Kiran Mupiri
#
#   3 BHK Apartment  for Sale in Hulimavu  		 ₹ 75.4 Lac 		 1565 sqft
# Sneha M
#
#   2 BHK Apartment  for Sale in Harlur  		 ₹ 62.2 Lac 		 1115 sqft
# Nagaraja Reddy
#
#   3 BHK Apartment  for Sale in Thanisandra  		 ₹ 1.02 Cr 		 1102 sqft
# Singh
#
#   4 BHK Apartment  for Sale in Malleshwaram  		 ₹ 4.40 Cr 		 3100 sqft
# Santosh
#
#   2 BHK Apartment  for Sale in Old Madras Road  		 ₹ 65.4 Lac 		 1399 sqft
# Shyam
#
#   3 BHK Apartment  for Sale in Old Madras Road  		 ₹ 1.09 Cr 		 1916 sqft
# Vishal
#
# ...

# %%
data = {
"propertyType_new":"10002_10003_10021_10022",
"city":"3327",
"mbTrackSrc":"homeSearchForm",
"searchType":"1",
"propertyType": "10002,10003,10021,10022",
"disWeb": "Y",
"category": "S",
"groupstart": "0",
"offset": "0",
"maxOffset": "0", 
"page": "3",
"ltrIds": "39817085,32194101,15269646,35809181,37968509,39116707,37122619,33836733,37758787,39258065,38468917,36010801,37994299,35508461,37361621,34235551,38568717,38814521,39364795,31075061,39363923,38492137,31774845,36435883,38465227,21787021,32196877,38169547,18552617,24938901"
}
response = requests.post("https://www.magicbricks.com/property-for-sale/residential-real-estate?proptype=Multistorey-Apartment,Builder-Floor-Apartment,Penthouse,Studio-Apartment&cityName=Bangalore",data=data)
soup = BeautifulSoup(response.content,"html.parser")

cards = soup.find_all("div",attrs = {"class":"m-srp-card__container"})
for card in cards:
    price = card.find("div", attrs={"class":"m-srp-card__price"})
    if price :
        price_text = price.text
    else:
        price_text = None
    title = card.find("a",attrs = {"class":"m-srp-card__title"})
    title_text = title.text.replace("\n", " ")
    area = card.find("div",attrs = {"class":"m-srp-card__summary__info"})
    if area:
        area_text = area.text
    else:
        area_text = None
    print("{} \t\t {} \t\t {}".format(title_text,price_text,area_text))
# Out:
#   3 BHK Apartment  for Sale in Kanakapura Road  		 ₹ 96.1 Lac 		 1841 sqft
#   4 BHK Apartment  for Sale in Rt Nagar  		 ₹ 5.16 Cr 		 3969 sqft
#   3 BHK Apartment  for Sale in Whitefield  		 ₹ 78.5 Lac 		 1600 sqft
#   2 BHK Apartment  for Sale in Sarjapur Road  		 ₹ 54.5 Lac 		 1229 sqft
#   3 BHK Apartment  for Sale in Electronics City Phase 1, Electronic City  		 ₹ 48 Lac 		 1455 sqft
#   3 BHK Apartment  for Sale in Hulimavu  		 ₹ 75.4 Lac 		 1565 sqft
#   2 BHK Apartment  for Sale in Harlur  		 ₹ 62.2 Lac 		 1115 sqft
#   3 BHK Apartment  for Sale in Thanisandra  		 ₹ 1.02 Cr 		 1102 sqft
#   4 BHK Apartment  for Sale in Malleshwaram  		 ₹ 4.40 Cr 		 3100 sqft
#   2 BHK Apartment  for Sale in Old Madras Road  		 ₹ 65.4 Lac 		 1399 sqft
#   3 BHK Apartment  for Sale in Old Madras Road  		 ₹ 1.09 Cr 		 1916 sqft
#   3 BHK Apartment  for Sale in Jp Nagar Phase 8  		 ₹ 91.9 Lac 		 1500 sqft
#   2 BHK Apartment  for Sale in Devanahalli  		 ₹ 45 Lac 		 885 sqft
# ...

# %%
def get_data(page_no):
    data = {
    "propertyType_new":"10002_10003_10021_10022",
    "city":"3327",
    "mbTrackSrc":"homeSearchForm",
    "searchType":"1",
    "propertyType": "10002,10003,10021,10022",
    "disWeb": "Y",
    "category": "S",
    "groupstart": "0",
    "offset": "0",
    "maxOffset": "0", 
    "page": page_no,
    "ltrIds": "39817085,32194101,15269646,35809181,37968509,39116707,37122619,33836733,37758787,39258065,38468917,36010801,37994299,35508461,37361621,34235551,38568717,38814521,39364795,31075061,39363923,38492137,31774845,36435883,38465227,21787021,32196877,38169547,18552617,24938901"
    }
    return data
    
for value in range(1,5):
    data = get_data(value)
    response = requests.post("https://www.magicbricks.com/property-for-sale/residential-real-estate?proptype=Multistorey-Apartment,Builder-Floor-Apartment,Penthouse,Studio-Apartment&cityName=Bangalore",data=data)
    soup = BeautifulSoup(response.content,"html.parser")

    cards = soup.find_all("div",attrs = {"class":"m-srp-card__container"})
    for card in cards:
        price = card.find("div", attrs={"class":"m-srp-card__price"})
        if price :
            price_text = price.text
        else:
            price_text = None
        title = card.find("a",attrs = {"class":"m-srp-card__title"})
        title_text = title.text.replace("\n", " ")
        area = card.find("div",attrs = {"class":"m-srp-card__summary__info"})
        if area:
            area_text = area.text
        else:
            area_text = None
        print("{} \t\t {} \t\t {}".format(title_text,price_text,area_text))
# Out:
#   3 BHK Apartment  for Sale in Kanakapura Road  		 ₹ 96.1 Lac 		 1841 sqft
#   4 BHK Apartment  for Sale in Rt Nagar  		 ₹ 5.16 Cr 		 3969 sqft
#   3 BHK Apartment  for Sale in Whitefield  		 ₹ 78.5 Lac 		 1600 sqft
#   2 BHK Apartment  for Sale in Sarjapur Road  		 ₹ 54.5 Lac 		 1229 sqft
#   3 BHK Apartment  for Sale in Electronics City Phase 1, Electronic City  		 ₹ 48 Lac 		 1455 sqft
#   3 BHK Apartment  for Sale in Hulimavu  		 ₹ 75.4 Lac 		 1565 sqft
#   2 BHK Apartment  for Sale in Harlur  		 ₹ 62.2 Lac 		 1115 sqft
#   3 BHK Apartment  for Sale in Thanisandra  		 ₹ 1.02 Cr 		 1102 sqft
#   4 BHK Apartment  for Sale in Malleshwaram  		 ₹ 4.40 Cr 		 3100 sqft
#   2 BHK Apartment  for Sale in Old Madras Road  		 ₹ 65.4 Lac 		 1399 sqft
#   3 BHK Apartment  for Sale in Old Madras Road  		 ₹ 1.09 Cr 		 1916 sqft
#   3 BHK Apartment  for Sale in Jp Nagar Phase 8  		 ₹ 91.9 Lac 		 1500 sqft
#   2 BHK Apartment  for Sale in Devanahalli  		 ₹ 45 Lac 		 885 sqft
# ...

# %%
Bs
scrapy
